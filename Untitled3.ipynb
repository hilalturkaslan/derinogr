# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow import keras
import tensorflow
import os

# %% [markdown]
# import numpy as np= Verileri modelleme kısmında matematiksel işlemler için kullanıldı import seaborn as sns = Görselleştirme kısmında veriyi anlamlı bir grafiğe dönüştürmek için kullanıldı import matplotlib.pyplot as plt = Veri görselleştirme işlemlerinin çoğunda kullanıldı. import pandas as pd = Verileri tablolama ve ön işleme aşamalarında kullanıldı. Pandas, NumPy, Seaborn,
# Matplotlib, Sklearn ve Tensorflow kitaplıklarını içe aktarıldı.

# %%
from pandas.io.parsers.readers import read_csv
df = pd.read_csv('labels.csv')

# %% [markdown]
# Projedeki labels kısmı yüklendi

# %%
df.head(5)
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %% [markdown]
# Veri setinin ilk 5 satırını getirir ve verinin yapısı hakkında ön bilgi verir.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10222 entries, 0 to 10221
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10222 non-null  object
#  1   breed   10222 non-null  object
# dtypes: object(2)
# memory usage: 159.8+ KB

# %%
df.shape
# Out:
# (10222, 2)

# %% [markdown]
# Veri setinin kaç satır ve sütundan oluştuğunu gösterir.

# %%
df.describe()
# Out:
#                                       id               breed
# count                              10222               10222
# unique                             10222                 120
# top     000bec180eb18c7604dcecc8fe0dba07  scottish_deerhound
# freq                                   1                 126

# %% [markdown]
# Veri setinin istatiki değerlerini gösterir.

# %%
def barw(ax):
  for i in ax.patches:
    val=p.get_witdh()
    x=p.get_x()+ p.get_witdh()
    y=p.get_y()+ p.get_height()/2
    ax.annotate(round(val,2),(x,y))

    plt.figure(figsize=(16,32))
    ax0=sns.countplot(y=label_dataframe['breed'],order=label_dataframe['breed'].value_counts().index)
    barw(ax0)
    plt.show()

# %%
classes = sorted(list(set(label_dataframe['breed'])))
n_classes = len(classes)
print('Total unique breed {}'.format(n_classes))

class_to_num = dict(zip(classes, range(n_classes)))
class_to_num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3690fa19994e> in <cell line: 1>()
# ----> 1 classes = sorted(list(set(label_dataframe['breed'])))
#       2 n_classes = len(classes)
#       3 print('Total unique breed {}'.format(n_classes))
#       4
#       5 class_to_num = dict(zip(classes, range(n_classes)))
#
# NameError: name 'label_dataframe' is not defined

# %%
input_shape = (331,331,3)
def images_to_array(directory, label_dataframe, target_size = input_shape):

  input_labels = label_dataframe['breed']
  images = np.zeros([len(label_dataframe),target_size[0],target_size[1],target_size[2]],dtype=np.unit0)
  y=np.zeros([len(label_dataframe),1],dtype=np.unit0)

  for ix, image_name in enumerate(tqdm(label_dataframe['id'].values)):
    img_dir = os.path.join(directory, image_name + '.jpg')
    img = load_img(img_dir, target_size=target_size)
    images[ix]=img

    del img

    dog_breed = image_labels[ix]
    y[ix] = class_to_num[dog_breed]

    y = to_categorical(y)
    return images.y

# %%
import time
t = time.time()

X,y = images_to_array('train', labels[:])

# %%
n = 25
plt.figure(figsize=(26,20))

for i in range(n):
  ax=plt.subplot(5,5,i+1)
  plt.title(classes[np.where(y[1]==1)[0][0]])
  plt.imshow(X[i].astype('int32'))

# %%
from pandas.io.parsers.readers import read_csv
df = pd.read_csv('sample.csv')

# %% [markdown]
# Projedeki sample submission kısmı yüklendi.

# %%
df.head(5)
# Out:
#                                  id  affenpinscher  afghan_hound  \
# 0  000621fb3cbb32d8935728e48679680e       0.008333      0.008333
# 1  00102ee9d8eb90812350685311fe5890       0.008333      0.008333
# 2  0012a730dfa437f5f3613fb75efcd4ce       0.008333      0.008333
# 3  001510bc8570bbeee98c8d80c8a95ec1       0.008333      0.008333
# 4  001a5f3114548acdefa3d4da05474c2e       0.008333      0.008333
#
#    african_hunting_dog  airedale  american_staffordshire_terrier  appenzeller  \
# 0             0.008333  0.008333                        0.008333     0.008333
# 1             0.008333  0.008333                        0.008333     0.008333
# 2             0.008333  0.008333                        0.008333     0.008333
# 3             0.008333  0.008333                        0.008333     0.008333
# 4             0.008333  0.008333                        0.008333     0.008333
#
#    australian_terrier   basenji    basset  ...  toy_poodle  toy_terrier  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7757 entries, 0 to 7756
# Columns: 121 entries, id to yorkshire_terrier
# dtypes: float64(120), object(1)
# memory usage: 7.2+ MB
